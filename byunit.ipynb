# %%
def month_converter(month):
    months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    return months.index(month) + 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://data.ontario.ca/dataset/f4f86e54-872d-43f8-8a86-3892fd3cb5e6/resource/8a88fe6d-d8fb-41a3-9d04-f0550a44999f/download/daily_change_in_cases_by_phu.csv')

# %%
df.shape
# Out:
# (391, 36)

# %%
df.head()
# Out:
#          Date  Algoma_Public_Health_Unit  Brant_County_Health_Unit  \
# 0  2020-03-24                        NaN                       NaN
# 1  2020-03-25                        0.0                       1.0
# 2  2020-03-26                        0.0                       0.0
# 3  2020-03-27                        0.0                       0.0
# 4  2020-03-28                        NaN                       NaN
#
#    Chatham-Kent_Health_Unit  Durham_Region_Health_Department  \
# 0                       NaN                              NaN
# 1                       0.0                              3.0
# 2                       0.0                              1.0
# 3                       0.0                              5.0
# 4                       NaN                              NaN
#
#    Eastern_Ontario_Health_Unit  Grey_Bruce_Health_Unit  \
# 0                          NaN                     NaN
# 1                          0.0                     1.0
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  Algoma Public Health Unit  Brant County Health Unit  \
# 0 2020-03-24                        NaN                       NaN
# 1 2020-03-25                        0.0                       1.0
# 2 2020-03-26                        0.0                       0.0
# 3 2020-03-27                        0.0                       0.0
# 4 2020-03-28                        NaN                       NaN
#
#    Chatham-Kent Health Unit  Durham Region Health Department  \
# 0                       NaN                              NaN
# 1                       0.0                              3.0
# 2                       0.0                              1.0
# 3                       0.0                              5.0
# 4                       NaN                              NaN
#
#    Eastern Ontario Health Unit  Grey Bruce Health Unit  \
# 0                          NaN                     NaN
# 1                          0.0                     1.0
# ...

# %%
df.columns=df.columns.str.replace('_', ' ')

# %%
top_5=list(df.mean().sort_values(ascending=False).head(6).index.drop('Total'))
# Out:
# <ipython-input-269-8fa382d9d5bb>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   top_5=list(df.mean().sort_values(ascending=False).head(6).index.drop('Total'))

# %%
top_5
# Out:
# ['Toronto Public Health',
#  'Peel Public Health',
#  'York Region Public Health Services',
#  'Ottawa Public Health',
#  'Durham Region Health Department']

# %%
df_5=df.drop([col for col in df.columns if col not in top_5 and col!='Date'], axis=1)
df_5.set_index('Date', inplace=True)
df_5
# Out:
#             Durham Region Health Department  Ottawa Public Health  \
# Date
# 2020-03-24                              NaN                   NaN
# 2020-03-25                              3.0                   3.0
# 2020-03-26                              1.0                   0.0
# 2020-03-27                              5.0                   5.0
# 2020-03-28                              NaN                   NaN
# ...                                     ...                   ...
# 2021-04-14                            248.0                 340.0
# 2021-04-15                            216.0                 342.0
# 2021-04-16                            268.0                 366.0
# 2021-04-17                            301.0                 251.0
# 2021-04-18                            279.0                 239.0
#
#             Peel Public Health  Toronto Public Health  \
# Date
# 2020-03-24                 NaN                    NaN
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 6))
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
df_5.plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='Date'>
